# %%
from manim import *
import numpy as np
# Out:
# Manim Community v0.17.3

# %%
# %%manim -qh -v WARNING sylvesterExpanded
# class sylvesterExpanded(Scene):
#     def construct(self):
#         title = Tex(r"Ecuación de Sylvester")
#         text = Text('')
#         eqns = VGroup(
#             MathTex("A"),
#             MathTex("X"),
#             MathTex("+"),
#             MathTex("X"),
#             MathTex("B"),
#             MathTex("="),
#             MathTex("C"),
#         ).arrange(RIGHT)
#
#         self.play(Write(title))
#         self.wait(1)
#         self.play(Unwrite(title))
#         self.play(Write(eqns))
#         self.wait(1)
#         matrix_form = VGroup(
#             Matrix("A"),
#             Matrix("X"),
#             MathTex("+"),
#             Matrix("X"),
#             Matrix("B"),
#             MathTex("="),
#             Matrix("C"),
#         ).arrange(RIGHT)
#         rnxn = VGroup(
#             MathTex("R^{nxn}").scale(0.7).next_to(matrix_form[0],UP),
#             MathTex("R^{nxn}").next_to(matrix_form[1],UP),
#             MathTex("R^{nxn}").next_to(matrix_form[3],UP),
#             MathTex("R^{nxn}").next_to(matrix_form[4],UP),
#             MathTex("R^{nxn}").next_to(matrix_form[6],UP),
#         )
#         self.play(ReplacementTransform(eqns, matrix_form))
#         self.wait(1)
#         self.play(FadeIn(rnxn[0][0], shift=UP))
# #         matrix_form_2 = VGroup(
# #             Matrix([["a_{1,1}","a_{1,2}"],["a_{2,1}","a_{2,2}"]]),
# #             Matrix([["x_{1,1}","x_{1,2}"],["x_{2,1}","x_{2,2}"]]),
# #             MathTex("+"),
# #             Matrix([["x_{1,1}","x_{1,2}"],["x_{2,1}","x_{2,2}"]]),
# #             Matrix([["b_{1,1}","b_{1,2}"],["b_{2,1}","b_{2,2}"]]),
# #             MathTex("="),
# #             Matrix([["c_{1,1}","c_{1,2}"],["c_{2,1}","c_{2,2}"]]),
# #         ).scale(0.7).arrange(RIGHT)
# #         self.play(ReplacementTransform(matrix_form,matrix_form_2))
# #         self.wait(1)
#
# #         matrix_form_3 = VGroup(
# #             Matrix([[2,3],[3,5]]),
# #             Matrix([["x_{1,1}","x_{1,2}"],["x_{2,1}","x_{2,2}"]]),
# #             MathTex("+"),
# #             Matrix([["x_{1,1}","x_{1,2}"],["x_{2,1}","x_{2,2}"]]),
# #             Matrix([[5,3],[7,2]]),
# #             MathTex("="),
# #             Matrix([[10,11],[12,13]]),
# #         ).scale(0.7).arrange(RIGHT)
#
# #         self.play(ReplacementTransform(matrix_form_2,matrix_form_3))
# #         matrix_form_4 = VGroup(
# #             Matrix([["2x_{1,1}+3x_{2,1}","2x_{1,2} + 3x_{2,2}"],
# #                     ["3x_{1,1} + 5x_{2,1}","3x_{1,2}+5x_{2,2}"]
# #                    ],h_buff=3.5),
# #             MathTex("+"),
# #             Matrix([["x_{1,1}","x_{1,2}"],["x_{2,1}","x_{2,2}"]]),
# #             Matrix([[5,3],[7,2]]),
# #             MathTex("="),
# #             Matrix([[10,11],[12,13]]),
# #         ).scale(0.7).arrange(RIGHT)
# #         matrix_form_5 = VGroup(
# #             Matrix([["2x_{1,1}+3x_{2,1}","2x_{1,2} + 3x_{2,2}"],
# #                     ["3x_{1,1} + 5x_{2,1}","3x_{1,2}+5x_{2,2}"]
# #                    ],h_buff=3.5),
# #             MathTex("+"),
# #             Matrix([["5x_{1,1}+7x_{1,2}", "3x_{1,1}+2x_{1,2}"],
# #         ["5x_{2,1} + 7x_{2,2}", "3x_{2,1}+2x_{2,2}"]
# #         ],h_buff=3.5),
# #             MathTex("="),
# #             Matrix([[10,11],[12,13]]),
# #         ).scale(0.7).arrange(RIGHT)
# #         self.play(ReplacementTransform(matrix_form_3,matrix_form_4))
# #         self.wait(2)
# #         self.play(ReplacementTransform(matrix_form_4,matrix_form_5))
# #         self.wait(2)
# #         matrix_form_6 = VGroup(
# #             Matrix([
# #                 ["7x_{1,1}+3x_{2,1}+7x_{1,2}","3x_{1,1}+4x_{1,2}+3x_{2,2}"],
# #                 ["3x_{1,1}+10x_{2,1}+7x_{2,2}","3x_{2,1}+3x_{1,2}+7x_{2,2}"]
# #                 ], h_buff = 5.5),
# #             MathTex("="),
# #             Matrix([[10,11],[12,13]])
# #         ).scale(0.7).arrange(RIGHT)
# #         self.play(ReplacementTransform(matrix_form_5,matrix_form_6))
# #         self.wait(2)
# #         self.play(ApplyMethod(matrix_form_6.to_edge, UP))
# #         values_left = matrix_form_6[0].copy().get_entries()
# #         values_right = matrix_form_6[2].copy().get_entries()
#
# #         eq1 = VGroup(
# #             values_left[0],
# #             MathTex("="),
# #             values_right[0]
# #         )
# #         eq2 = VGroup(
# #             values_left[2],
# #             MathTex("="),
# #             values_right[2]
# #         )
# #         eq3 = VGroup(
# #             values_left[1],
# #             MathTex("="),
# #             values_right[1]
# #         )
# #         eq4 = VGroup(
# #             values_left[3],
# #             MathTex("="),
# #             values_right[3]
# #         )
# #         self.wait(1)
# #         scale = 1.25
# #         self.play(*[Indicate(eq1[i], scale_factor = scale) for i in [0,2]])
# #         self.play(ApplyMethod(eq1.arrange, RIGHT))
# #         self.play(ApplyMethod(eq1.next_to, matrix_form_6,DOWN))
# #         self.wait(1)
# #         self.play(*[Indicate(eq2[i],scale_factor = scale) for i in [0,2]])
# #         self.play(ApplyMethod(eq2.arrange, RIGHT))
# #         self.play(ApplyMethod(eq2.next_to, eq1,DOWN))
#
# #         self.wait(1)
# #         self.play(*[Indicate(eq3[i],scale_factor = scale) for i in [0,2]])
# #         self.play(ApplyMethod(eq3.arrange, RIGHT))
# #         self.play(ApplyMethod(eq3.next_to, eq2,DOWN))
#
# #         self.wait(1)
# #         self.play(*[Indicate(eq4[i],scale_factor = scale) for i in [0,2]])
# #         self.play(ApplyMethod(eq4.arrange, RIGHT))
# #         self.play(ApplyMethod(eq4.next_to, eq3,DOWN))
#
# #         eqns = VGroup(eq1,eq2,eq3,eq4)
# #         self.play(ApplyMethod(eqns.move_to, ORIGIN))
# #         self.play(Unwrite(matrix_form_6))
# #         final_matrix_right = VGroup(
# #             eq1[2].copy(),
# #             eq2[2].copy(),
# #             eq3[2].copy(),
# #             eq4[2].copy(),
# #         )
# #         self.play(ApplyMethod(eqns.scale, 0.9))
# #         self.play(ApplyMethod(eqns.to_edge, UP))
# #         final_matrix_right = VGroup(
# #             eq1[2].copy(),
# #             eq2[2].copy(),
# #             eq3[2].copy(),
# #             eq4[2].copy(),
# #         )
# #         final_matrix_left = VGroup(
# #             eq1[0].copy(),
# #             eq2[0].copy(),
# #             eq3[0].copy(),
# #             eq4[0].copy(),
# #         )
# #         final_matrix = VGroup(
# #             Matrix([
# #                 [7,3,7,0],
# #                 [3,10,0,7],
# #                 [3,0,4,3],
# #                 [0,3,3,7]
# #                 ]),
# #             Matrix([["x_{1,1}"],["x_{2,1}"],["x_{1,2}"],["x_{2,2}"]]),
# #             MathTex("="),
# #             Matrix([
# #                 [10],
# #                 [12],
# #                 [11],
# #                 [13],
# #             ])
# #         ).scale(0.7).arrange(RIGHT).move_to(DOWN)
# #         self.play(Write(final_matrix[1]),Write(final_matrix[2]))
# #         self.play(ReplacementTransform(final_matrix_right, final_matrix[3]))
# #         self.play(Write(final_matrix[0].get_brackets()))
# #         self.play(ReplacementTransform(final_matrix_left[0], final_matrix[0].get_rows()[0]))
# #         self.play(ReplacementTransform(final_matrix_left[1], final_matrix[0].get_rows()[1]))
# #         self.play(ReplacementTransform(final_matrix_left[2], final_matrix[0].get_rows()[2]))
# #         self.play(ReplacementTransform(final_matrix_left[3], final_matrix[0].get_rows()[3]))
# #         self.wait(2)
# #         self.play(Unwrite(eqns))
# #         self.play(ApplyMethod(final_matrix.move_to, ORIGIN))
# #         self.wait(2)
# #         self.play(FadeOut(final_matrix[2:]))
# #         self.wait()
# #         self.play(ApplyMethod(final_matrix[:2].move_to,ORIGIN))
# #         v_ = np.array([[1,2,3,4]]).T
# #         v = Matrix(v_).scale(0.7).move_to(final_matrix[1])
# #         self.play(ReplacementTransform(final_matrix[1],v))
# #         self.wait()
# #         result_ = np.array([
# #             [34, 27],
# #             [51, 43]
# #         ])
# #         resultFlat = Matrix(np.array([result_.flatten(order = 'F').T]))
# #         self.play(ReplacementTransform(VGroup(final_matrix[:3],v),resultFlat))
#         self.wait(2)
# Out:
# <video src="media/jupyter/sylvesterExpanded@2023-12-18@00-18-10.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -qh -v WARNING afun
# import numpy as np
# class afun(Scene):
#     def construct(self):
#         code_ = """
# v = np.array([1,2,3,4])
# X = np.reshape(v, (2,2), order = 'F')
# A = np.array([
#     [2,3],
#     [3,5]
# ])
# B = np.array([
#     [5,3],
#     [7,2]
# ])
#
# result = A @ X + X @ B
#
# result = result.flatten('F')
# """
#         code = Code(code = code_,language="python", style=Code.styles_list[15]).scale(0.7)
#         self.play(Write(code))
#         self.wait(1)
#         self.play(ApplyMethod(code.to_edge, LEFT))
#         v_ = np.array([[1,2,3,4]]).T
#         v = Matrix(v_).scale(0.7).move_to(RIGHT*3.5)
#         #
#
#         vnxn_ = np.reshape(v_,(2,2), order = 'F')
#         vnxn = Matrix(vnxn_).scale(0.7).move_to(v)
#         sylvester = VGroup(
#             Matrix([[2,3],[3,5]]),
#             Matrix(vnxn_),
#             MathTex("+"),
#             Matrix(vnxn_),
#             Matrix([[5,3],[7,2]]),
#         ).scale(0.5).arrange(RIGHT).move_to(vnxn)
#         result_ = np.array([
#             [34, 27],
#             [51, 43]
#         ])
#         resultFlat = np.array([result_.flatten(order = 'F').T])
#         result = VGroup(
#             Matrix(result_).move_to(vnxn),
#             Matrix(resultFlat).move_to(vnxn)
#         ).scale(0.7)
#
#         self.play(Indicate(code[2][0]))
#         self.play(Write(v))
#         self.wait
#         self.play(Indicate(code[2][1]))
#         self.play(ReplacementTransform(v, vnxn))
#         self.wait()
#         self.play(Indicate(code[2][11]))
#         self.play(ReplacementTransform(vnxn, sylvester))
#         self.wait()
#         self.play(ReplacementTransform(sylvester, result[0]))
#         self.wait()
#         self.play(Indicate(code[2][13]))
#         self.play(ReplacementTransform(result[0], result[1]))
#         self.wait(2)
#         code_final_ = """
# def afun(v):
#     #Primero se hace un "reshape"
#     #del vector "v" de dimensión n^2,
#     #a una matriz X de dimensión nxn
#     X = np.reshape(v, (n,n), order = 'F')
#     #Ecuación de Sylvester
#     out = A @ X + X @ B
#     # Se aplica el operador "vec" a la matriz "out"
#     # y se retorna
#     return out.flatten('F')
# """
#         code_final = Code(code = code_final_,language="python", style=Code.styles_list[15]).scale(0.7).to_edge(LEFT)
#         self.play(ReplacementTransform(code, code_final),Unwrite(result[1]))
#         self.play(ApplyMethod(code_final.move_to, ORIGIN))
#
#         self.wait(2)
# Out:
# <video src="media/jupyter/afun@2023-09-10@17-23-25.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -qh -v WARNING conclusion
# class conclusion(Scene):
#     def construct(self):
#         v_ = np.array([0.5,1,1.5,5])
#         A_ = np.array([
#                 [2,3],
#                 [3,5]
#             ])
#         B_ = np.array([
#                 [5,3],
#                 [7,2]
#             ])
#         sol_matrix_ = np.array([[17. , 22.5], [46.5, 42.5]])
#         sol_flatten_ = [sol_matrix_.flatten('F')]
#         v = Matrix([v_]).scale(0.7).to_edge(UP)
#
#         self.play(Write(v))
#
#         syl_form_1 = VGroup(
#             Matrix([[2,3],[3,5]]),
#             Matrix([["v_{1,1}","v_{1,2}"],["v_{2,1}","v_{2,2}"]]),
#             MathTex("+"),
#             Matrix([["v_{1,1}","v_{1,2}"],["v_{2,1}","v_{2,2}"]]),
#             Matrix([[5,3],[7,2]]),
#         ).scale(0.5).arrange(RIGHT)
#
#         final_matrix = VGroup(
#             Matrix([
#                 [7,3,7,0],
#                 [3,10,0,7],
#                 [3,0,4,3],
#                 [0,3,3,7]
#                 ]),
#             Matrix([["v_{1,1}"],["v_{2,1}"],["v_{1,2}"],["v_{2,2}"]]),
#         ).scale(0.7).arrange(RIGHT)
#
#         self.play(Write(syl_form_1))
#         self.wait()
#         self.play(ReplacementTransform(syl_form_1, final_matrix))
#         self.wait()
#         self.play(ApplyMethod(final_matrix.to_edge, LEFT))
#
#         v_copy1 =VGroup(
#             v.copy(),
#             Matrix([
#                 [0.5],
#                 [1.0],
#                 [1.5],
#                 [5.0],
#             ]).scale(0.7).move_to(final_matrix[-1])
#         )
#         v_copy2 =VGroup(
#             v.copy(),
#             Matrix([
#                 [0.5],
#                 [1.0],
#                 [1.5],
#                 [5.0],
#             ]).scale(0.7).move_to(ORIGIN)
#         )
#
#
#         self.play(ReplacementTransform(v_copy1[0],v_copy1[1]), FadeOut(final_matrix[-1], run_time=1))
#         self.wait(2)
#
#         self.play(ReplacementTransform(v_copy2[0],v_copy2[1]))
#
#         self.play(ApplyMethod(v_copy2[1].move_to,3*RIGHT))
#
#         v_reshaped = Matrix(np.reshape(v_,(2,2),order='F')).scale(0.7).move_to(v_copy2[1])
#         afun = VGroup(
#             Matrix([[2,3],[3,5]]),
#             Matrix(np.reshape(v_,(2,2),order='F')),
#             MathTex("+"),
#             Matrix(np.reshape(v_,(2,2),order='F')),
#             Matrix([[5,3],[7,2]]),
#         ).scale(0.7).arrange(RIGHT).to_edge(RIGHT)
#         sol = VGroup(
#             Matrix(sol_matrix_),
#             Matrix(sol_flatten_)
#         ).scale(0.7).move_to(afun[3])
#         code_group = VGroup(
#             Code(code = "X = np.reshape(vector,(2,2), order = 'F')", language="python", style=Code.styles_list[15]).next_to(v_copy2[1],UP),
#             Code(code = "out = A@X + X@B",language="python", style=Code.styles_list[15]).next_to(v_reshaped,UP),
#         ).scale(0.5)
#         self.play(FadeIn(code_group[0],shift=UP))
#         self.play(ReplacementTransform(v_copy2[1], v_reshaped))
#         self.play(FadeOut(code_group[0], shift=UP))
#         self.play(FadeIn(code_group[1], shift=UP))
#         self.play(ReplacementTransform(v_reshaped, afun))
#         self.play(FadeOut(code_group[1], shift=UP))
#         out = Code(code = "out.flatten('F')",language="python", style=Code.styles_list[15]).next_to(sol[0], UP).scale(0.5)
#
#         self.wait()
#         sol2 = Matrix(
#             [[17.0, 46.5, 22.5, 42.5]]
#         ).scale(0.7).move_to(final_matrix)
#         to_transform = VGroup(final_matrix, v_copy1[1])
#
#         self.play(ReplacementTransform(afun,sol[0]))
#         self.play(FadeIn(out, shift=UP))
#         self.play(ReplacementTransform(sol[0],sol[1]),ReplacementTransform(to_transform,sol2), FadeOut(v))
#         self.play(FadeOut(out, shift=UP))
#         self.wait()
#         self.play(ApplyMethod(sol2.move_to, ORIGIN),ApplyMethod(sol[1].move_to, ORIGIN))
#         solfinal =  Matrix(
#             [[17.0, 46.5, 22.5, 42.5]]
#         ).scale(0.7)
#         self.play(ApplyMethod(sol2.move_to, ORIGIN),ApplyMethod(sol[1].move_to, ORIGIN))
#         #self.play(ReplacementTransform(VGroup(sol2, sol[1]),solfinal))
#         self.wait(1)
# Out:
# <video src="media/jupyter/conclusion@2023-09-10@17-24-33.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%manim -qh -v WARNING merge
# class merge(Scene):
#     def clean(self):
#         self.play(
#             *[FadeOut(mob)for mob in self.mobjects]
#         )
#     def construct(self):
#         title = Tex(r"Ecuación de Sylvester")
#         eqns = VGroup(
#             MathTex("A"),
#             MathTex("X"),
#             MathTex("+"),
#             MathTex("X"),
#             MathTex("B"),
#             MathTex("="),
#             MathTex("C"),
#         ).arrange(RIGHT)
#
#         self.play(Write(title))
#         self.wait(1)
#         self.play(Unwrite(title))
#         self.play(Write(eqns))
#         self.wait(1)
#         matrix_form = VGroup(
#             Matrix("A"),
#             Matrix("X"),
#             MathTex("+"),
#             Matrix("X"),
#             Matrix("B"),
#             MathTex("="),
#             Matrix("C"),
#         ).arrange(RIGHT)
#         self.play(ReplacementTransform(eqns, matrix_form))
#         self.wait(1)
#         matrix_form_2 = VGroup(
#             Matrix([["a_{1,1}","a_{1,2}"],["a_{2,1}","a_{2,2}"]]),
#             Matrix([["x_{1,1}","x_{1,2}"],["x_{2,1}","x_{2,2}"]]),
#             MathTex("+"),
#             Matrix([["x_{1,1}","x_{1,2}"],["x_{2,1}","x_{2,2}"]]),
#             Matrix([["b_{1,1}","b_{1,2}"],["b_{2,1}","b_{2,2}"]]),
#             MathTex("="),
#             Matrix([["c_{1,1}","c_{1,2}"],["c_{2,1}","c_{2,2}"]]),
#         ).scale(0.7).arrange(RIGHT)
#         self.play(ReplacementTransform(matrix_form,matrix_form_2))
#         self.wait(1)
#
#         matrix_form_3 = VGroup(
#             Matrix([[2,3],[3,5]]),
#             Matrix([["x_{1,1}","x_{1,2}"],["x_{2,1}","x_{2,2}"]]),
#             MathTex("+"),
#             Matrix([["x_{1,1}","x_{1,2}"],["x_{2,1}","x_{2,2}"]]),
#             Matrix([[5,3],[7,2]]),
#             MathTex("="),
#             Matrix([[10,11],[12,13]]),
#         ).scale(0.7).arrange(RIGHT)
#
#         self.play(ReplacementTransform(matrix_form_2,matrix_form_3))
#         matrix_form_4 = VGroup(
#             Matrix([["2x_{1,1}+3x_{2,1}","2x_{1,2} + 3x_{2,2}"],
#                     ["3x_{1,1} + 5x_{2,1}","3x_{1,2}+5x_{2,2}"]
#                    ],h_buff=3.5),
#             MathTex("+"),
#             Matrix([["x_{1,1}","x_{1,2}"],["x_{2,1}","x_{2,2}"]]),
#             Matrix([[5,3],[7,2]]),
#             MathTex("="),
#             Matrix([[10,11],[12,13]]),
#         ).scale(0.7).arrange(RIGHT)
#         matrix_form_5 = VGroup(
#             Matrix([["2x_{1,1}+3x_{2,1}","2x_{1,2} + 3x_{2,2}"],
#                     ["3x_{1,1} + 5x_{2,1}","3x_{1,2}+5x_{2,2}"]
#                    ],h_buff=3.5),
#             MathTex("+"),
#             Matrix([["5x_{1,1}+7x_{1,2}", "3x_{1,1}+2x_{1,2}"],
#         ["5x_{2,1} + 7x_{2,2}", "3x_{2,1}+2x_{2,2}"]
#         ],h_buff=3.5),
#             MathTex("="),
#             Matrix([[10,11],[12,13]]),
#         ).scale(0.7).arrange(RIGHT)
#         self.play(ReplacementTransform(matrix_form_3,matrix_form_4))
#         self.wait(2)
#         self.play(ReplacementTransform(matrix_form_4,matrix_form_5))
#         self.wait(2)
#         matrix_form_6 = VGroup(
#             Matrix([
#                 ["7x_{1,1}+3x_{2,1}+7x_{1,2}","3x_{1,1}+4x_{1,2}+3x_{2,2}"],
#                 ["3x_{1,1}+10x_{2,1}+7x_{2,2}","3x_{2,1}+3x_{1,2}+7x_{2,2}"]
#                 ], h_buff = 5.5),
#             MathTex("="),
#             Matrix([[10,11],[12,13]])
#         ).scale(0.7).arrange(RIGHT)
#         self.play(ReplacementTransform(matrix_form_5,matrix_form_6))
#         self.wait(2)
#         self.play(ApplyMethod(matrix_form_6.to_edge, UP))
#         values_left = matrix_form_6[0].copy().get_entries()
#         values_right = matrix_form_6[2].copy().get_entries()
#
#         eq1 = VGroup(
#             values_left[0],
#             MathTex("="),
#             values_right[0]
#         )
#         eq2 = VGroup(
#             values_left[2],
#             MathTex("="),
#             values_right[2]
#         )
#         eq3 = VGroup(
#             values_left[1],
#             MathTex("="),
#             values_right[1]
#         )
#         eq4 = VGroup(
#             values_left[3],
#             MathTex("="),
#             values_right[3]
#         )
#         self.wait(1)
#         scale = 1.25
#         self.play(*[Indicate(eq1[i], scale_factor = scale) for i in [0,2]])
#         self.play(ApplyMethod(eq1.arrange, RIGHT))
#         self.play(ApplyMethod(eq1.next_to, matrix_form_6,DOWN))
#         self.wait(1)
#         self.play(*[Indicate(eq2[i],scale_factor = scale) for i in [0,2]])
#         self.play(ApplyMethod(eq2.arrange, RIGHT))
#         self.play(ApplyMethod(eq2.next_to, eq1,DOWN))
#
#         self.wait(1)
#         self.play(*[Indicate(eq3[i],scale_factor = scale) for i in [0,2]])
#         self.play(ApplyMethod(eq3.arrange, RIGHT))
#         self.play(ApplyMethod(eq3.next_to, eq2,DOWN))
#
#         self.wait(1)
#         self.play(*[Indicate(eq4[i],scale_factor = scale) for i in [0,2]])
#         self.play(ApplyMethod(eq4.arrange, RIGHT))
#         self.play(ApplyMethod(eq4.next_to, eq3,DOWN))
#
#         eqns = VGroup(eq1,eq2,eq3,eq4)
#         self.play(ApplyMethod(eqns.move_to, ORIGIN))
#         self.play(Unwrite(matrix_form_6))
#         final_matrix_right = VGroup(
#             eq1[2].copy(),
#             eq2[2].copy(),
#             eq3[2].copy(),
#             eq4[2].copy(),
#         )
#         self.play(ApplyMethod(eqns.scale, 0.9))
#         self.play(ApplyMethod(eqns.to_edge, UP))
#         final_matrix_right = VGroup(
#             eq1[2].copy(),
#             eq2[2].copy(),
#             eq3[2].copy(),
#             eq4[2].copy(),
#         )
#         final_matrix_left = VGroup(
#             eq1[0].copy(),
#             eq2[0].copy(),
#             eq3[0].copy(),
#             eq4[0].copy(),
#         )
#         final_matrix = VGroup(
#             Matrix([
#                 [7,3,7,0],
#                 [3,10,0,7],
#                 [3,0,4,3],
#                 [0,3,3,7]
#                 ]),
#             Matrix([["x_{1,1}"],["x_{2,1}"],["x_{1,2}"],["x_{2,2}"]]),
#             MathTex("="),
#             Matrix([
#                 [10],
#                 [12],
#                 [11],
#                 [13],
#             ])
#         ).scale(0.7).arrange(RIGHT).move_to(DOWN)
#         self.play(Write(final_matrix[1]),Write(final_matrix[2]))
#         self.play(ReplacementTransform(final_matrix_right, final_matrix[3]))
#         self.play(Write(final_matrix[0].get_brackets()))
#         self.play(ReplacementTransform(final_matrix_left[0], final_matrix[0].get_rows()[0]))
#         self.play(ReplacementTransform(final_matrix_left[1], final_matrix[0].get_rows()[1]))
#         self.play(ReplacementTransform(final_matrix_left[2], final_matrix[0].get_rows()[2]))
#         self.play(ReplacementTransform(final_matrix_left[3], final_matrix[0].get_rows()[3]))
#         self.wait(2)
#         self.play(Unwrite(eqns))
#         self.play(ApplyMethod(final_matrix.move_to, ORIGIN))
#         self.wait(2)
#
#         self.play(FadeOut(final_matrix[2:]))
#         self.wait()
#         self.play(ApplyMethod(final_matrix[:2].move_to,ORIGIN))
#         v_ = np.array([[1,2,3,4]]).T
#         v = Matrix(v_).scale(0.7).move_to(final_matrix[1])
#         self.play(ReplacementTransform(final_matrix[1],v))
#         self.wait()
#         result_ = np.array([
#             [34, 27],
#             [51, 43]
#         ])
#         resultFlat = Matrix(np.array([result_.flatten(order = 'F').T]))
#         self.play(ReplacementTransform(VGroup(final_matrix[:3],v),resultFlat))
#         self.wait(2)
#         ####################
#         self.clean()
#         ####################
#         code_ = """
# v = np.array([1,2,3,4])
# X = np.reshape(v, (2,2), order = 'F')
# A = np.array([
#     [2,3],
#     [3,5]
# ])
# B = np.array([
#     [5,3],
#     [7,2]
# ])
#
# result = A @ X + X @ B
#
# result = result.flatten('F')
# """
#         code = Code(code = code_,language="python", style=Code.styles_list[15]).scale(0.7)
#         self.play(Write(code))
#         self.wait(1)
#         self.play(ApplyMethod(code.to_edge, LEFT))
#         v_ = np.array([[1,2,3,4]]).T
#         v = Matrix(v_).scale(0.7).move_to(RIGHT*3.5)
#         #
#
#         vnxn_ = np.reshape(v_,(2,2), order = 'F')
#         vnxn = Matrix(vnxn_).scale(0.7).move_to(v)
#         sylvester = VGroup(
#             Matrix([[2,3],[3,5]]),
#             Matrix(vnxn_),
#             MathTex("+"),
#             Matrix(vnxn_),
#             Matrix([[5,3],[7,2]]),
#         ).scale(0.5).arrange(RIGHT).move_to(vnxn)
#         result_ = np.array([
#             [34, 27],
#             [51, 43]
#         ])
#         resultFlat = np.array([result_.flatten(order = 'F').T])
#         result = VGroup(
#             Matrix(result_).move_to(vnxn),
#             Matrix(resultFlat).move_to(vnxn)
#         ).scale(0.7)
#
#         self.play(Indicate(code[2][0]))
#         self.play(Write(v))
#         self.wait
#         self.play(Indicate(code[2][1]))
#         self.play(ReplacementTransform(v, vnxn))
#         self.wait()
#         self.play(Indicate(code[2][11]))
#         self.play(ReplacementTransform(vnxn, sylvester))
#         self.wait()
#         self.play(ReplacementTransform(sylvester, result[0]))
#         self.wait()
#         self.play(Indicate(code[2][13]))
#         self.play(ReplacementTransform(result[0], result[1]))
#         self.wait(2)
#         code_final_ = """
# def afun(v):
#     #Primero se hace un "reshape"
#     #del vector "v" de dimensión n^2,
#     #a una matriz X de dimensión nxn
#     X = np.reshape(v, (n,n), order = 'F')
#     #Ecuación de Sylvester
#     out = A @ X + X @ B
#     # Se aplica el operador "vec" a la matriz "out"
#     # y se retorna
#     return out.flatten('F')
# """
#         code_final = Code(code = code_final_,language="python", style=Code.styles_list[15]).scale(0.7).to_edge(LEFT)
#         self.play(ReplacementTransform(code, code_final),Unwrite(result[1]))
#         self.play(ApplyMethod(code_final.move_to, ORIGIN))
#
#         self.wait(2)
#
# #######################################
#         self.clean()
# #######################################
#         v_ = np.array([0.5,1,1.5,5])
#         A_ = np.array([
#                 [2,3],
#                 [3,5]
#             ])
#         B_ = np.array([
#                 [5,3],
#                 [7,2]
#             ])
#         sol_matrix_ = np.array([[17. , 22.5], [46.5, 42.5]])
#         sol_flatten_ = [sol_matrix_.flatten('F')]
#         v = Matrix([v_]).scale(0.7).to_edge(UP)
#
#         self.play(Write(v))
#
#         syl_form_1 = VGroup(
#             Matrix([[2,3],[3,5]]),
#             Matrix([["v_{1,1}","v_{1,2}"],["v_{2,1}","v_{2,2}"]]),
#             MathTex("+"),
#             Matrix([["v_{1,1}","v_{1,2}"],["v_{2,1}","v_{2,2}"]]),
#             Matrix([[5,3],[7,2]]),
#         ).scale(0.5).arrange(RIGHT)
#
#         final_matrix = VGroup(
#             Matrix([
#                 [7,3,7,0],
#                 [3,10,0,7],
#                 [3,0,4,3],
#                 [0,3,3,7]
#                 ]),
#             Matrix([["v_{1,1}"],["v_{2,1}"],["v_{1,2}"],["v_{2,2}"]]),
#         ).scale(0.7).arrange(RIGHT)
#
#         self.play(Write(syl_form_1))
#         self.wait()
#         self.play(ReplacementTransform(syl_form_1, final_matrix))
#         self.wait()
#         self.play(ApplyMethod(final_matrix.to_edge, LEFT))
#
#         v_copy1 =VGroup(
#             v.copy(),
#             Matrix([
#                 [0.5],
#                 [1.0],
#                 [1.5],
#                 [5.0],
#             ]).scale(0.7).move_to(final_matrix[-1])
#         )
#         v_copy2 =VGroup(
#             v.copy(),
#             Matrix([
#                 [0.5],
#                 [1.0],
#                 [1.5],
#                 [5.0],
#             ]).scale(0.7).move_to(ORIGIN)
#         )
#
#
#         self.play(ReplacementTransform(v_copy1[0],v_copy1[1]), FadeOut(final_matrix[-1], run_time=1))
#         self.wait(2)
#
#         self.play(ReplacementTransform(v_copy2[0],v_copy2[1]))
#
#         self.play(ApplyMethod(v_copy2[1].move_to,3*RIGHT))
#
#         v_reshaped = Matrix(np.reshape(v_,(2,2),order='F')).scale(0.7).move_to(v_copy2[1])
#         afun = VGroup(
#             Matrix([[2,3],[3,5]]),
#             Matrix(np.reshape(v_,(2,2),order='F')),
#             MathTex("+"),
#             Matrix(np.reshape(v_,(2,2),order='F')),
#             Matrix([[5,3],[7,2]]),
#         ).scale(0.7).arrange(RIGHT).to_edge(RIGHT)
#         sol = VGroup(
#             Matrix(sol_matrix_),
#             Matrix(sol_flatten_)
#         ).scale(0.7).move_to(afun[3])
#         code_group = VGroup(
#             Code(code = "X = np.reshape(vector,(2,2), order = 'F')", language="python", style=Code.styles_list[15]).next_to(v_copy2[1],UP),
#             Code(code = "out = A@X + X@B",language="python", style=Code.styles_list[15]).next_to(v_reshaped,UP),
#         ).scale(0.5)
#         self.play(FadeIn(code_group[0],shift=UP))
#         self.play(ReplacementTransform(v_copy2[1], v_reshaped))
#         self.play(FadeOut(code_group[0], shift=UP))
#         self.play(FadeIn(code_group[1], shift=UP))
#         self.play(ReplacementTransform(v_reshaped, afun))
#         self.play(FadeOut(code_group[1], shift=UP))
#         out = Code(code = "out.flatten('F')",language="python", style=Code.styles_list[15]).next_to(sol[0], UP).scale(0.5)
#
#         self.wait()
#         sol2 = Matrix(
#             [[17.0, 46.5, 22.5, 42.5]]
#         ).scale(0.7).move_to(final_matrix)
#         to_transform = VGroup(final_matrix, v_copy1[1])
#
#         self.play(ReplacementTransform(afun,sol[0]))
#         self.play(FadeIn(out, shift=UP))
#         self.play(ReplacementTransform(sol[0],sol[1]),ReplacementTransform(to_transform,sol2), FadeOut(v))
#         self.play(FadeOut(out, shift=UP))
#         self.wait()
#         self.play(ApplyMethod(sol2.move_to, ORIGIN),ApplyMethod(sol[1].move_to, ORIGIN))
#         solfinal =  Matrix(
#             [[17.0, 46.5, 22.5, 42.5]]
#         ).scale(0.7)
#         self.play(ApplyMethod(sol2.move_to, ORIGIN),ApplyMethod(sol[1].move_to, ORIGIN))
#         #self.play(ReplacementTransform(VGroup(sol2, sol[1]),solfinal))
#         self.wait(3)
# Out:
# <video src="media/jupyter/merge@2023-09-10@17-26-14.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>
